# %% [markdown]
# ## Strukturiertes Programmieren mit Python 3

# %% [markdown]
# ### Beispiel: Fahrkartenautomat

# %%
import time

def main(args):

    # Fahrkarte wählen (Preis eingeben)
    # ---------------------------------
    print("Zu zahlender Betrag (EURO): ", end = "")
    zu_zahlender_betrag = float(input())

    # Geldeinwurf
    # -----------
    eingezahlter_gesamtbetrag = 0.0
    while eingezahlter_gesamtbetrag < zu_zahlender_betrag:
        print("Noch zu zahlen: %.2f" %(zu_zahlender_betrag - eingezahlter_gesamtbetrag))
        print("Eingabe (mind. 5Ct, höchstens 2 Euro): ", end = "")
        eingeworfene_münze = float(input())
        eingezahlter_gesamtbetrag += eingeworfene_münze

    # Fahrscheinausgabe
    # -----------------
    print("\nFahrschein wird ausgegeben")
    for i in range(0, 8, 1):
        print("=", end = "")
        time.sleep(0.25)
    print("\n\n")

    # Rückgeldberechnung und -ausgabe
    # -------------------------------
    rueckgabebetrag = eingezahlter_gesamtbetrag - zu_zahlender_betrag;
    if rückgabebetrag > 0.0:
        print("Der Rückgabebetrag in Höhe von %.2f EURO" %rückgabebetrag)
        print("wird in folgenden Münzen ausgezahlt:")

        while rückgabebetrag >= 2.0: # 2 EURO-Münzen
            print("2 EURO")
            rückgabebetrag -= 2.0
        while rückgabebetrag >= 1.0: # 1 EURO-Münzen
            print("1 EURO")
            rückgabebetrag -= 1.0
        while rückgabebetrag >= 0.5: # 50 CENT-Münzen
            print("50 CENT")
            rückgabebetrag -= 0.5
        while rückgabebetrag >= 0.2: # 20 CENT-Münzen
            print("20 CENT")
            rückgabebetrag -= 0.2
        while rückgabebetrag >= 0.1: # 10 CENT-Münzen
            print("10 CENT")
            rückgabebetrag -= 0.1
        while rückgabebetrag >= 0.05: # 5 CENT-Münzen
            print("5 CENT")
            rückgabebetrag -= 0.05

    print("\nVergessen Sie nicht, den Fahrschein\n"+
          "vor Fahrtantritt entwerten zu lassen!\n"+
          "Wir wünschen Ihnen eine gute Fahrt.\n")

main("")
# Out:
# Zu zahlender Betrag (EURO):
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 57
#      51             rückgabebetrag -= 0.05
#      53     print("\nVergessen Sie nicht, den Fahrschein\n"+
#      54           "vor Fahrtantritt entwerten zu lassen!\n"+
#      55           "Wir wünschen Ihnen eine gute Fahrt.\n")
# ---> 57 main("")
#
# Cell In[3], line 8, in main(args)
#       3 def main(args):
#       4
#       5     # Fahrkarte wählen (Preis eingeben)
#       6     # ---------------------------------
#       7     print("Zu zahlender Betrag (EURO): ", end = "")
# ----> 8     zu_zahlender_betrag = float(input())
#      10     # Geldeinwurf
#      11     # -----------
#      12     eingezahlter_gesamtbetrag = 0.0;
#
# ValueError: could not convert string to float: ''

# %% [markdown]
# ### Aufgabe:
#  Definieren Sie für die 4 Phasen des Fahrkartenautomaten die Funktionen
#   - fahrkarte_wählen()
#   - geld_einwerfen(zu_zahlen)
#   - fahrkarte_ausgeben()
#   - rückgeld_ausgeben(rückgabebetrag)

# %%
import time

def main(args):
    zu_zahlen = fahrkarte_waehlen()
    rueckgabebetrag = geld_einwerfen(zu_zahlen)
    fahrkarte_ausgeben()
    rueckgeld_ausgeben(rueckgabebetrag)

def fahrkarte_waehlen():
    print("Zu zahlender Betrag (EURO): ", end = "")
    return float(input())

def geld_einwerfen(zu_zahlen):
    zu_zahlender_betrag = zu_zahlen
    eingezahlter_gesamtbetrag = 0.0
    while eingezahlter_gesamtbetrag < zu_zahlender_betrag:
        print("Noch zu zahlen: %.2f" %(zu_zahlender_betrag - eingezahlter_gesamtbetrag))
        print("Eingabe (mind. 5Ct, höchstens 2 Euro): ", end = "")
        eingeworfene_münze = float(input())
        eingezahlter_gesamtbetrag += eingeworfene_münze
    return eingezahlter_gesamtbetrag - zu_zahlender_betrag


def fahrkarte_ausgeben():
    print("\nFahrschein wird ausgegeben")
    for i in range(0, 8, 1):
        print("=", end = "")
        time.sleep(0.25)
    print("\n\n")

def rueckgeld_ausgeben(rueckgabebetrag):
    if rueckgabebetrag > 0.0:
        print("Der rueckgabebetrag in Höhe von %.2f EURO" %rueckgabebetrag)
        print("wird in folgenden Münzen ausgezahlt:")

        while rueckgabebetrag >= 2.0: # 2 EURO-Münzen
            print("2 EURO")
            rueckgabebetrag -= 2.0
        while rueckgabebetrag >= 1.0: # 1 EURO-Münzen
            print("1 EURO")
            rueckgabebetrag -= 1.0
        while rueckgabebetrag >= 0.5: # 50 CENT-Münzen
            print("50 CENT")
            rueckgabebetrag -= 0.5
        while rueckgabebetrag >= 0.2: # 20 CENT-Münzen
            print("20 CENT")
            rueckgabebetrag -= 0.2
        while rueckgabebetrag >= 0.1: # 10 CENT-Münzen
            print("10 CENT")
            rueckgabebetrag -= 0.1
        while rueckgabebetrag >= 0.05: # 5 CENT-Münzen
            print("5 CENT")
            rueckgabebetrag -= 0.05

    print("\nVergessen Sie nicht, den Fahrschein\n"+
          "vor Fahrtantritt entwerten zu lassen!\n"+
          "Wir wünschen Ihnen eine gute Fahrt.\n")

main("")
# Out:
# Zu zahlender Betrag (EURO): Noch zu zahlen: 30.40
# Eingabe (mind. 5Ct, höchstens 2 Euro): Noch zu zahlen: 25.40
# Eingabe (mind. 5Ct, höchstens 2 Euro): Noch zu zahlen: 23.40
# Eingabe (mind. 5Ct, höchstens 2 Euro): Noch zu zahlen: 21.40
# Eingabe (mind. 5Ct, höchstens 2 Euro): Noch zu zahlen: 19.40
# Eingabe (mind. 5Ct, höchstens 2 Euro): Noch zu zahlen: 17.40
# Eingabe (mind. 5Ct, höchstens 2 Euro): Noch zu zahlen: 15.40
# Eingabe (mind. 5Ct, höchstens 2 Euro): Noch zu zahlen: 13.40
# Eingabe (mind. 5Ct, höchstens 2 Euro): Noch zu zahlen: 11.40
# Eingabe (mind. 5Ct, höchstens 2 Euro): Noch zu zahlen: 9.40
# Eingabe (mind. 5Ct, höchstens 2 Euro): Noch zu zahlen: 7.40
# Eingabe (mind. 5Ct, höchstens 2 Euro): Noch zu zahlen: 5.40
# Eingabe (mind. 5Ct, höchstens 2 Euro): Noch zu zahlen: 3.40
# Eingabe (mind. 5Ct, höchstens 2 Euro): Noch zu zahlen: 1.40
# Eingabe (mind. 5Ct, höchstens 2 Euro):
# Fahrschein wird ausgegeben
# ========
#
#
# Der rueckgabebetrag in Höhe von 0.60 EURO
# wird in folgenden Münzen ausgezahlt:
# 50 CENT
# 10 CENT
#
# Vergessen Sie nicht, den Fahrschein
# vor Fahrtantritt entwerten zu lassen!
# Wir wünschen Ihnen eine gute Fahrt.

# %% [markdown]
# ### Aufgabe:
# Der Fahrkartenautomat soll nach Beendigung eines Kaufvorgangs für weitere Kaufvorgänge bereit sein.
# Das Programm soll also in einer Endlosschleife wiederholt werden.

# %%
import time

def main(args):
    zu_zahlen = fahrkarte_waehlen()
    rueckgabebetrag = geld_einwerfen(zu_zahlen)
    fahrkarte_ausgeben()
    rueckgeld_ausgeben(rueckgabebetrag)

def fahrkarte_waehlen():
    print("Zu zahlender Betrag (EURO): ", end = "")
    return float(input())

def geld_einwerfen(zu_zahlen):
    zu_zahlender_betrag = zu_zahlen
    eingezahlter_gesamtbetrag = 0.0
    while eingezahlter_gesamtbetrag < zu_zahlender_betrag:
        print("Noch zu zahlen: %.2f" %(zu_zahlender_betrag - eingezahlter_gesamtbetrag))
        print("Eingabe (mind. 5Ct, höchstens 2 Euro): ", end = "")
        eingeworfene_münze = float(input())
        eingezahlter_gesamtbetrag += eingeworfene_münze
    return eingezahlter_gesamtbetrag - zu_zahlender_betrag


def fahrkarte_ausgeben():
    print("\nFahrschein wird ausgegeben")
    for i in range(0, 8, 1):
        print("=", end = "")
        time.sleep(0.25)
    print("\n\n")

def rueckgeld_ausgeben(rueckgabebetrag):
    if rueckgabebetrag > 0.0:
        print("Der rueckgabebetrag in Höhe von %.2f EURO" %rueckgabebetrag)
        print("wird in folgenden Münzen ausgezahlt:")

        while rueckgabebetrag >= 2.0: # 2 EURO-Münzen
            print("2 EURO")
            rueckgabebetrag -= 2.0
        while rueckgabebetrag >= 1.0: # 1 EURO-Münzen
            print("1 EURO")
            rueckgabebetrag -= 1.0
        while rueckgabebetrag >= 0.5: # 50 CENT-Münzen
            print("50 CENT")
            rueckgabebetrag -= 0.5
        while rueckgabebetrag >= 0.2: # 20 CENT-Münzen
            print("20 CENT")
            rueckgabebetrag -= 0.2
        while rueckgabebetrag >= 0.1: # 10 CENT-Münzen
            print("10 CENT")
            rueckgabebetrag -= 0.1
        while rueckgabebetrag >= 0.05: # 5 CENT-Münzen
            print("5 CENT")
            rueckgabebetrag -= 0.05

    print("\nVergessen Sie nicht, den Fahrschein\n"+
          "vor Fahrtantritt entwerten zu lassen!\n"+
          "Wir wünschen Ihnen eine gute Fahrt.\n")

while True:
  main("")
